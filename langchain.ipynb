# %% [markdown]
# #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

# %%
# !conda create -n mylangchainproject python=3.10 --yes # uses python 3.10 because the LangFlow gui editor but dont worry about that for now
# Out:
# Channels:
#  - apple
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/Utilities/anaconda3/envs/mylangchainproject
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.11.26 |       hca03da5_0         132 KB
#     openssl-3.0.15             |       h80987f9_0         4.3 MB
#     pip-24.2                   |  py310hca03da5_0         2.3 MB
#     python-3.10.15             |       hb885b13_1        13.0 MB
#     setuptools-75.1.0          |  py310hca03da5_0         1.7 MB
#     tzdata-2024b               |       h04d1e81_0         115 KB
#     wheel-0.44.0               |  py310hca03da5_0         111 KB
#     ------------------------------------------------------------
#                                            Total:        21.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/osx-arm64::bzip2-1.0.8-h80987f9_6
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-2024.11.26-hca03da5_0
#   libffi             pkgs/main/osx-arm64::libffi-3.4.4-hca03da5_1
#   ncurses            pkgs/main/osx-arm64::ncurses-6.4-h313beb8_0
#   openssl            pkgs/main/osx-arm64::openssl-3.0.15-h80987f9_0
#   pip                pkgs/main/osx-arm64::pip-24.2-py310hca03da5_0
#   python             pkgs/main/osx-arm64::python-3.10.15-hb885b13_1
#   readline           pkgs/main/osx-arm64::readline-8.2-h1a28f6b_0
#   setuptools         pkgs/main/osx-arm64::setuptools-75.1.0-py310hca03da5_0
#   sqlite             pkgs/main/osx-arm64::sqlite-3.45.3-h80987f9_0
#   tk                 pkgs/main/osx-arm64::tk-8.6.14-h6ba3021_0
#   tzdata             pkgs/main/noarch::tzdata-2024b-h04d1e81_0
#   wheel              pkgs/main/osx-arm64::wheel-0.44.0-py310hca03da5_0
#   xz                 pkgs/main/osx-arm64::xz-5.4.6-h80987f9_1
#   zlib               pkgs/main/osx-arm64::zlib-1.2.13-h18a0788_1
#
#
#
# Downloading and Extracting Packages:
# python-3.10.15       | 13.0 MB   |                                       |   0%
# openssl-3.0.15       | 4.3 MB    |                                       |   0%
#
# pip-24.2             | 2.3 MB    |                                       |   0%
#
#
# setuptools-75.1.0    | 1.7 MB    |                                       |   0%
#
#
#
# ca-certificates-2024 | 132 KB    |                                       |   0%
#
#
#
#
# tzdata-2024b         | 115 KB    |                                       |   0%
#
#
#
#
#
# wheel-0.44.0         | 111 KB    |                                       |   0%
#
# pip-24.2             | 2.3 MB    | 2                                     |   1%
#
#
# python-3.10.15       | 13.0 MB   |                                       |   0%
# openssl-3.0.15       | 4.3 MB    | 1                                     |   0%
#
#
#
# ca-certificates-2024 | 132 KB    | ####4                                 |  12%
#
# pip-24.2             | 2.3 MB    | ###2                                  |   9%
#
#
# setuptools-75.1.0    | 1.7 MB    | ####1                                 |  11%
#
#
#
# ca-certificates-2024 | 132 KB    | ##################################### | 100%
#
#
#
# ca-certificates-2024 | 132 KB    | ##################################### | 100%
#
# pip-24.2             | 2.3 MB    | ######                                |  16%
# openssl-3.0.15       | 4.3 MB    | 6                                     |   2%
#
#
#
#
# python-3.10.15       | 13.0 MB   | 3                                     |   1%
#
# pip-24.2             | 2.3 MB    | ########3                             |  23%
#
#
# setuptools-75.1.0    | 1.7 MB    | #####9                                |  16%
# python-3.10.15       | 13.0 MB   | 7                                     |   2%
#
#
# setuptools-75.1.0    | 1.7 MB    | ########3                             |  23%
# openssl-3.0.15       | 4.3 MB    | ####7                                 |  13%
#
# python-3.10.15       | 13.0 MB   | ##3                                   |   6%
# openssl-3.0.15       | 4.3 MB    | ##########7                           |  29%
#
# pip-24.2             | 2.3 MB    | ##########################1           |  71%
#
#
# setuptools-75.1.0    | 1.7 MB    | ###################5                  |  53%
#
#
# setuptools-75.1.0    | 1.7 MB    | #######################6              |  64%
# openssl-3.0.15       | 4.3 MB    | #############5                        |  37%
#
# python-3.10.15       | 13.0 MB   | ###                                   |   8%
#
#
# setuptools-75.1.0    | 1.7 MB    | ###########################1          |  73%
#
# pip-24.2             | 2.3 MB    | ####################################7 |  99%
# python-3.10.15       | 13.0 MB   | ####2                                 |  12%
#
#
# setuptools-75.1.0    | 1.7 MB    | ################################      |  87%
#
#
#
#
#
# wheel-0.44.0         | 111 KB    | #####3                                |  14%
# openssl-3.0.15       | 4.3 MB    | #####################9                |  59%
#
#
# python-3.10.15       | 13.0 MB   | #####                                 |  14%
#
#
#
#
#
# wheel-0.44.0         | 111 KB    | ##################################### | 100%
# openssl-3.0.15       | 4.3 MB    | ###########################1          |  73%
#
# python-3.10.15       | 13.0 MB   | #####7                                |  16%
#
#
# python-3.10.15       | 13.0 MB   | ######4                               |  17%
# openssl-3.0.15       | 4.3 MB    | ##############################8       |  83%
#
#
#
#
# python-3.10.15       | 13.0 MB   | #######3                              |  20%
# openssl-3.0.15       | 4.3 MB    | ##################################2   |  92%
#
#
#
#
# tzdata-2024b         | 115 KB    | ##################################### | 100%
#
#
#
#
# python-3.10.15       | 13.0 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate mylangchainproject
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
#!conda update conda --yes
#!conda activate mylangchainproject
#!source activate base
# !conda init --all
# !conda init bash
#!conda activate my-env
# Out:
# no change     /Applications/Utilities/anaconda3/condabin/conda
# no change     /Applications/Utilities/anaconda3/bin/conda
# no change     /Applications/Utilities/anaconda3/bin/conda-env
# no change     /Applications/Utilities/anaconda3/bin/activate
# no change     /Applications/Utilities/anaconda3/bin/deactivate
# no change     /Applications/Utilities/anaconda3/etc/profile.d/conda.sh
# no change     /Applications/Utilities/anaconda3/etc/fish/conf.d/conda.fish
# no change     /Applications/Utilities/anaconda3/shell/condabin/Conda.psm1
# modified      /Applications/Utilities/anaconda3/shell/condabin/conda-hook.ps1
# no change     /Applications/Utilities/anaconda3/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /Applications/Utilities/anaconda3/etc/profile.d/conda.csh
# no change     /Users/nandini/.bash_profile
# no change     /Users/nandini/.zshrc
# no change     /Users/nandini/.config/fish/config.fish
# no change     /Users/nandini/.xonshrc
# no change     /Users/nandini/.tcshrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# no change     /Applications/Utilities/anaconda3/condabin/conda
# no change     /Applications/Utilities/anaconda3/bin/conda
# no change     /Applications/Utilities/anaconda3/bin/conda-env
# no change     /Applications/Utilities/anaconda3/bin/activate
# no change     /Applications/Utilities/anaconda3/bin/deactivate
# no change     /Applications/Utilities/anaconda3/etc/profile.d/conda.sh
# no change     /Applications/Utilities/anaconda3/etc/fish/conf.d/conda.fish
# no change     /Applications/Utilities/anaconda3/shell/condabin/Conda.psm1
# no change     /Applications/Utilities/anaconda3/shell/condabin/conda-hook.ps1
# no change     /Applications/Utilities/anaconda3/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /Applications/Utilities/anaconda3/etc/profile.d/conda.csh
# no change     /Users/nandini/.bash_profile
# No action taken.

# %%
# !conda activate mylangchainproject
# Out:
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !pip install langchain python-dotenv openai
# Out:
# Requirement already satisfied: langchain in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (0.3.9)
# Requirement already satisfied: python-dotenv in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (0.21.0)
# Requirement already satisfied: openai in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (1.55.3)
# Requirement already satisfied: PyYAML>=5.3 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (2.10.2)
# Requirement already satisfied: requests<3,>=2 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (0.8.0)
# Requirement already satisfied: sniffio in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: idna>=2.8 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/Utilities/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (2.1)

# %%
#main.ipynb
import os # for accessing environment variables
from dotenv import load_dotenv # for loading environment variables from .env file
from abc import ABC, abstractmethod # abstract class, dont worry about this yet I will explain later in another article

# imports from langchain package
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate

# load environment variables from .env file
load_dotenv() 
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY","key") 
llm = OpenAI(openai_api_key=OPENAI_API_KEY) # Language Model
chat_model = ChatOpenAI(openai_api_key=OPENAI_API_KEY) # Another LLM interface
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       4 from abc import ABC, abstractmethod # abstract class, dont worry about this yet I will explain later in another article
#       6 # imports from langchain package
#       7 #from langchain.llms import OpenAI
# ----> 8 from langchain.chat_models import ChatOpenAI
#       9 from langchain.prompts import PromptTemplate
#      11 # load environment variables from .env file
#
# File /Applications/Utilities/anaconda3/lib/python3.12/site-packages/langchain/chat_models/__init__.py:29, in __getattr__(name)
#      28 def __getattr__(name: str) -> None:
# ---> 29     from langchain_community import chat_models
#      31     # If not in interactive env, raise warning.
#      32     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
question = "What is a flower?"
# use llm.predict to get the answer
answer = llm.predict(question).strip()
print(question)
print(answer)
# use chat_model.predict to get the answer
answer = chat_model.predict(question).strip()
print(question)
print(answer)

#implementing prompt template for chatbot to enable parameterized questions
promptTemplate = PromptTemplate.from_template(
    "What is {topic} in the context of {context}?"
    )

# this format the prompt template with the given parameters
prompt = promptTemplate.format(
    topic="a flower", 
    context="philosophy")

print(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 question = "What is a flower?"
#       2 # use llm.predict to get the answer
# ----> 3 answer = llm.predict(question).strip()
#       4 print(question)
#       5 print(answer)
#
# NameError: name 'llm' is not defined

# %%
def get_answer(topic, context):
    """
    This function returns the answer to the question "What is {topic} in the context of {context}?"
    in dictionary format
    """
    promptTemplate = PromptTemplate.from_template(
    "What is {topic} in the context of {context}?"
    )
    question = promptTemplate.format(
        topic=topic, 
        context=context)
    answer = chat_model.predict(question).strip()
    return {"question": question, "answer": answer}

pp = pprint.PrettyPrinter(indent=4) # for pretty printing the output
pp.pprint(get_answer("the meaning of life", "biology"))
pp.pprint(get_answer("the meaning of life", "philosophy"))
pp.pprint(get_answer("the meaning of life", "physics"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 15
#      12     answer = chat_model.predict(question).strip()
#      13     return {"question": question, "answer": answer}
# ---> 15 pp = pprint.PrettyPrinter(indent=4) # for pretty printing the output
#      16 pp.pprint(get_answer("the meaning of life", "biology"))
#      17 pp.pprint(get_answer("the meaning of life", "philosophy"))
#
# NameError: name 'pprint' is not defined
